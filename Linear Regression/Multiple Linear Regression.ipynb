# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Shubh\players.csv")

# %%
df.head()
# Out:
#    id                          name  now_cost position     team  \
# 0   1               Folarin Balogun        45      FWD  Arsenal
# 1   2           Cédric Alves Soares        40      DEF  Arsenal
# 2   3                Mohamed Elneny        45      MID  Arsenal
# 3   4         Fábio Ferreira Vieira        55      MID  Arsenal
# 4   5  Gabriel dos Santos Magalhães        50      DEF  Arsenal
#
#    expected_goals  expected_goal_involvements_per_90  transfers_out_event  \
# 0             0.0                                0.0                 2263
# 1             0.0                                0.0                  892
# 2             0.0                                0.0                 1236
# 3             0.0                                0.0                  547
# 4             0.0                                0.0                50090
#
#    ict_index_rank_type  expected_goals_per_90  ...  creativity_rank  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 657 entries, 0 to 656
# Data columns (total 72 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    657 non-null    int64
#  1   name                                  657 non-null    object
#  2   now_cost                              657 non-null    int64
#  3   position                              657 non-null    object
#  4   team                                  657 non-null    object
#  5   expected_goals                        657 non-null    float64
#  6   expected_goal_involvements_per_90     657 non-null    float64
#  7   transfers_out_event                   657 non-null    int64
#  8   ict_index_rank_type                   657 non-null    int64
#  9   expected_goals_per_90                 657 non-null    float64
#  10  starts_per_90                         657 non-null    float64
# ...
